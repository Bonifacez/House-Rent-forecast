# %% [markdown]
# ## 模型选择

# %%
import lightgbm as lgb
import sklearn
import numpy
import hyperopt
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials
import colorama
import numpy as np
from sklearn.model_selection import KFold
import pandas as pd
from sklearn.metrics import r2_score

# %%
N_HYPEROPT_PROBES = 500
HYPEROPT_ALGO = tpe.suggest  #  tpe.suggest OR hyperopt.rand.suggest

# ----------------------------------------------------------

colorama.init()

# ---------------------------------------------------------------------

def get_lgb_params(space):
    lgb_params = dict()
    lgb_params['boosting_type'] = space['boosting_type'] if 'boosting_type' in space else 'gbdt'
    lgb_params['objective'] = 'regression'
    lgb_params['metric'] = 'rmse'
    lgb_params['learning_rate'] = space['learning_rate']
    lgb_params['num_leaves'] = int(space['num_leaves'])
    lgb_params['min_data_in_leaf'] = int(space['min_data_in_leaf'])
    lgb_params['min_sum_hessian_in_leaf'] = space['min_sum_hessian_in_leaf']
    lgb_params['max_depth'] = -1
    lgb_params['lambda_l1'] = space['lambda_l1'] if 'lambda_l1' in space else 0.0
    lgb_params['lambda_l2'] = space['lambda_l2'] if 'lambda_l2' in space else 0.0
    lgb_params['max_bin'] = int(space['max_bin']) if 'max_bin' in space else 256
    lgb_params['feature_fraction'] = space['feature_fraction']
    lgb_params['bagging_fraction'] = space['bagging_fraction']
    lgb_params['bagging_freq'] = int(space['bagging_freq']) if 'bagging_freq' in space else 1
    lgb_params['nthread'] = 4
    return lgb_params

# ---------------------------------------------------------------------

obj_call_count = 0
cur_best_score = 0 # 0 or np.inf
log_writer = open( 'lgb-hyperopt-log.txt', 'w' )

X_train = pd.read_csv('C:/Users/Boniface/Desktop/房租预测/datasets/cluster_train.csv')
Y_train = X_train.pop('tradeMoney')
X_train.pop('Unnamed: 0')

def objective(space):
    global obj_call_count, cur_best_score

    obj_call_count += 1

    print('\nLightGBM objective call #{} cur_best_score={:7.5f}'.format(obj_call_count,cur_best_score) )

    lgb_params = get_lgb_params(space)

    sorted_params = sorted(space.items(), key=lambda z: z[0])
    params_str = str.join(' ', ['{}={}'.format(k, v) for k, v in sorted_params])
    print('Params: {}'.format(params_str) )
    
    kf = KFold(n_splits=3, shuffle=True, random_state=0)
    out_of_fold = np.zeros(len(X_train))
    for fold, (train_idx, val_idx) in enumerate(kf.split(X_train)):
        D_train = lgb.Dataset(X_train.iloc[train_idx], label=Y_train[train_idx])
        D_val = lgb.Dataset(X_train.iloc[val_idx], label=Y_train[val_idx])
        # Train
        num_round = 10000
        clf = lgb.train(lgb_params,
                           D_train,
                           num_boost_round=num_round,
                           # metrics='mlogloss',
                           valid_sets=D_val,
                           # valid_names='val',
                           # fobj=None,
                           # feval=None,
                           # init_model=None,
                           # feature_name='auto',
                           # categorical_feature='auto',
                           early_stopping_rounds=200,
                           # evals_result=None,
                           verbose_eval=False,
                           # learning_rates=None,
                           # keep_training_booster=False,
                           # callbacks=None
                           )
        # predict
        nb_trees = clf.best_iteration
        val_loss = clf.best_score['valid_0']
        print('nb_trees={} val_loss={}'.format(nb_trees, val_loss))
        out_of_fold[val_idx] = clf.predict(X_train.iloc[val_idx], num_iteration=nb_trees)
        score = r2_score(out_of_fold, Y_train)

    print('val_r2_score={}'.format(score))

    log_writer.write('score={} Params:{} nb_trees={}\n'.format(score, params_str, nb_trees ))
    log_writer.flush()

    if score>cur_best_score:
        cur_best_score = score
        print(colorama.Fore.GREEN + 'NEW BEST SCORE={}'.format(cur_best_score) + colorama.Fore.RESET)
    return {'loss': -score, 'status': STATUS_OK}

# --------------------------------------------------------------------------------

space ={
        'num_leaves': hp.quniform ('num_leaves', 10, 100, 1),
        'min_data_in_leaf':  hp.quniform ('min_data_in_leaf', 10, 100, 1),
        'feature_fraction': hp.uniform('feature_fraction', 0.75, 1.0),
        'bagging_fraction': hp.uniform('bagging_fraction', 0.75, 1.0),
        'learning_rate': hp.uniform('learning_rate', 0, 0.01),
#         'learning_rate': hp.loguniform('learning_rate', -5.0, -2.3),
        'min_sum_hessian_in_leaf': hp.loguniform('min_sum_hessian_in_leaf', 0, 2.3),
        'max_bin': hp.quniform ('max_bin', 88, 200, 1),
        'bagging_freq': hp.quniform ('bagging_freq', 1, 15, 1),
        'lambda_l1': hp.uniform('lambda_l1', 0, 10 ),
        'lambda_l2': hp.uniform('lambda_l2', 0, 10 ),
       }

trials = Trials()
best = hyperopt.fmin(fn=objective,
                     space=space,
                     algo=HYPEROPT_ALGO,
                     max_evals=N_HYPEROPT_PROBES,
                     trials=trials,
                     verbose=1)

print('-'*50)
print('The best params:')
print( best )
print('\n\n')
# Out:
#
# LightGBM objective call #1 cur_best_score=0.00000
# Params: bagging_fraction=0.8820937983441063 bagging_freq=14.0 feature_fraction=0.8704557633084408 lambda_l1=8.060932625512262 lambda_l2=6.349607742388661 learning_rate=0.0030055585045688517 max_bin=104.0 min_data_in_leaf=82.0 min_sum_hessian_in_leaf=9.76848183297411 num_leaves=42.0
# nb_trees=9997 val_loss=OrderedDict([('rmse', 728.756269703204)])
# nb_trees=10000 val_loss=OrderedDict([('rmse', 770.0866364148336)])
# nb_trees=10000 val_loss=OrderedDict([('rmse', 732.3867670208512)])
# val_r2_score=0.9017680011634658
# NEW BEST SCORE=0.9017680011634658
#
# LightGBM objective call #2 cur_best_score=0.90177
# Params: bagging_fraction=0.7554166617166741 bagging_freq=12.0 feature_fraction=0.8258412633150126 lambda_l1=6.616188671526509 lambda_l2=0.7393280585231665 learning_rate=0.006363405106362656 max_bin=171.0 min_data_in_leaf=11.0 min_sum_hessian_in_leaf=7.443023445274145 num_leaves=24.0
# nb_trees=9989 val_loss=OrderedDict([('rmse', 720.4549874291383)])
# nb_trees=9986 val_loss=OrderedDict([('rmse', 765.9119644835899)])
# nb_trees=6878 val_loss=OrderedDict([('rmse', 732.5582683219634)])
# val_r2_score=0.9029333505250106
# NEW BEST SCORE=0.9029333505250106
#
# LightGBM objective call #3 cur_best_score=0.90293
# Params: bagging_fraction=0.7770810032135298 bagging_freq=8.0 feature_fraction=0.8217168807903108 lambda_l1=5.312501079707506 lambda_l2=6.185950697602703 learning_rate=0.004623439424177775 max_bin=156.0 min_data_in_leaf=44.0 min_sum_hessian_in_leaf=3.204515746199552 num_leaves=84.0
# nb_trees=6369 val_loss=OrderedDict([('rmse', 724.5056943423954)])
# nb_trees=4756 val_loss=OrderedDict([('rmse', 765.9169492181746)])
# nb_trees=4497 val_loss=OrderedDict([('rmse', 730.6832634458248)])
# val_r2_score=0.903121153944653
# NEW BEST SCORE=0.903121153944653
#
# LightGBM objective call #4 cur_best_score=0.90312
# Params: bagging_fraction=0.9174438299092492 bagging_freq=9.0 feature_fraction=0.9795600263196719 lambda_l1=0.7156444214991431 lambda_l2=1.9833122520988922 learning_rate=0.007129072296333499 max_bin=117.0 min_data_in_leaf=45.0 min_sum_hessian_in_leaf=2.9977321521368845 num_leaves=92.0
# nb_trees=3753 val_loss=OrderedDict([('rmse', 727.1273500231808)])
# nb_trees=2996 val_loss=OrderedDict([('rmse', 772.9525176516248)])
# nb_trees=2394 val_loss=OrderedDict([('rmse', 739.9135910839498)])
# val_r2_score=0.9015125994586285
#
# LightGBM objective call #5 cur_best_score=0.90312
# Params: bagging_fraction=0.7508843061587889 bagging_freq=3.0 feature_fraction=0.8449441402870965 lambda_l1=2.526410833657231 lambda_l2=5.937078836182107 learning_rate=0.007920771402578247 max_bin=90.0 min_data_in_leaf=22.0 min_sum_hessian_in_leaf=2.1260417804730616 num_leaves=10.0
# nb_trees=10000 val_loss=OrderedDict([('rmse', 740.4550197063344)])
# nb_trees=10000 val_loss=OrderedDict([('rmse', 780.4598212820628)])
# nb_trees=9997 val_loss=OrderedDict([('rmse', 743.5109923164173)])
# val_r2_score=0.8980360627299177
#
# LightGBM objective call #6 cur_best_score=0.90312
# Params: bagging_fraction=0.840840103572913 bagging_freq=3.0 feature_fraction=0.804786874306418 lambda_l1=5.651963914038911 lambda_l2=5.027552615872012 learning_rate=0.002935033503916045 max_bin=197.0 min_data_in_leaf=14.0 min_sum_hessian_in_leaf=1.951022542638509 num_leaves=60.0
# nb_trees=10000 val_loss=OrderedDict([('rmse', 722.0390469513677)])
# nb_trees=9990 val_loss=OrderedDict([('rmse', 764.9186225253515)])
# nb_trees=9591 val_loss=OrderedDict([('rmse', 727.6836915456466)])
# val_r2_score=0.9033307704948463
# NEW BEST SCORE=0.9033307704948463
#
# LightGBM objective call #7 cur_best_score=0.90333
# Params: bagging_fraction=0.9667774005641162 bagging_freq=7.0 feature_fraction=0.7577354643036633 lambda_l1=9.505249751818756 lambda_l2=1.4651026816561674 learning_rate=0.0031588512010122874 max_bin=181.0 min_data_in_leaf=41.0 min_sum_hessian_in_leaf=2.40764422943478 num_leaves=68.0
# nb_trees=9996 val_loss=OrderedDict([('rmse', 722.5177505554525)])
# nb_trees=9997 val_loss=OrderedDict([('rmse', 766.7985382806388)])
# nb_trees=8596 val_loss=OrderedDict([('rmse', 729.7108515642943)])
# val_r2_score=0.9032885337608471
#
# LightGBM objective call #8 cur_best_score=0.90333
# Params: bagging_fraction=0.7585249603238389 bagging_freq=15.0 feature_fraction=0.877140610537062 lambda_l1=6.6964016801262805 lambda_l2=1.4888946877679077 learning_rate=0.007669564095520026 max_bin=189.0 min_data_in_leaf=14.0 min_sum_hessian_in_leaf=2.217506913093206 num_leaves=62.0
# nb_trees=4230 val_loss=OrderedDict([('rmse', 722.2182135856553)])
# nb_trees=4410 val_loss=OrderedDict([('rmse', 766.6920188694492)])
# nb_trees=3119 val_loss=OrderedDict([('rmse', 731.268644636675)])
# val_r2_score=0.903153226892303
#
# LightGBM objective call #9 cur_best_score=0.90333
# Params: bagging_fraction=0.7568016080006144 bagging_freq=15.0 feature_fraction=0.811204158863872 lambda_l1=5.870380488404773 lambda_l2=3.3764702932526047 learning_rate=0.006226799360833106 max_bin=184.0 min_data_in_leaf=61.0 min_sum_hessian_in_leaf=4.202696382160081 num_leaves=22.0
#   2%|▋                                          | 8/500 [39:30<40:29:50, 296.32s/trial, best loss: -0.9033307704948463]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-a88530f802f0> in <module>
#     114                      max_evals=N_HYPEROPT_PROBES,
#     115                      trials=trials,
# --> 116                      verbose=1)
#     117
#     118 print('-'*50)
#
# D:\Anaconda3\lib\site-packages\hyperopt\fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar)
#     480             catch_eval_exceptions=catch_eval_exceptions,
#     481             return_argmin=return_argmin,
# --> 482             show_progressbar=show_progressbar,
#     483         )
#     484
#
# D:\Anaconda3\lib\site-packages\hyperopt\base.py in fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar)
#     684             catch_eval_exceptions=catch_eval_exceptions,
#     685             return_argmin=return_argmin,
# --> 686             show_progressbar=show_progressbar,
#     687         )
#     688
#
# D:\Anaconda3\lib\site-packages\hyperopt\fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar)
#     507
#     508     # next line is where the fmin is actually executed
# --> 509     rval.exhaust()
#     510
#     511     if return_argmin:
#
# D:\Anaconda3\lib\site-packages\hyperopt\fmin.py in exhaust(self)
#     328     def exhaust(self):
#     329         n_done = len(self.trials)
# --> 330         self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     331         self.trials.refresh()
#     332         return self
#
# D:\Anaconda3\lib\site-packages\hyperopt\fmin.py in run(self, N, block_until_done)
#     284                 else:
#     285                     # -- loop over trials and do the jobs directly
# --> 286                     self.serial_evaluate()
#     287
#     288                 self.trials.refresh()
#
# D:\Anaconda3\lib\site-packages\hyperopt\fmin.py in serial_evaluate(self, N)
#     163                 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     164                 try:
# --> 165                     result = self.domain.evaluate(spec, ctrl)
#     166                 except Exception as e:
#     167                     logger.error("job exception: %s" % str(e))
#
# D:\Anaconda3\lib\site-packages\hyperopt\base.py in evaluate(self, config, ctrl, attach_attachments)
#     892                 print_node_on_error=self.rec_eval_print_node_on_error,
#     893             )
# --> 894             rval = self.fn(pyll_rval)
#     895
#     896         if isinstance(rval, (float, int, np.number)):
#
# <ipython-input-19-a88530f802f0> in objective(space)
#      70                            early_stopping_rounds=200,
#      71                            # evals_result=None,
# ---> 72                            verbose_eval=False,
#      73                            # learning_rates=None,
#      74                            # keep_training_booster=False,
#
# D:\Anaconda3\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     247                                     evaluation_result_list=None))
#     248
# --> 249         booster.update(fobj=fobj)
#     250
#     251         evaluation_result_list = []
#
# D:\Anaconda3\lib\site-packages\lightgbm\basic.py in update(self, train_set, fobj)
#    1974             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1975                 self.handle,
# -> 1976                 ctypes.byref(is_finished)))
#    1977             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1978             return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
lgb_best_params_space = {'bagging_fraction': 0.7767407798955681, 'bagging_freq': 1.0, 'feature_fraction': 0.8777729558158374, 'lambda_l1': 5.345467708327675, 'lambda_l2': 5.553820084786194, 'learning_rate': 0.006729207978658059, 'max_bin': 189.0, 'min_data_in_leaf': 27.0, 'min_sum_hessian_in_leaf': 3.9732496490135323, 'num_leaves': 41.0}

lgb_params = get_lgb_params(lgb_best_params_space)

kf = KFold(n_splits=3, shuffle=True, random_state=0)
out_of_fold = np.zeros(len(X_train))
for fold, (train_idx, val_idx) in enumerate(kf.split(X_train)):
        D_train = lgb.Dataset(X_train.iloc[train_idx], label=Y_train[train_idx])
        D_val = lgb.Dataset(X_train.iloc[val_idx], label=Y_train[val_idx])
        # Train
        num_round = 10000
        clf = lgb.train(lgb_params,
                           D_train,
                           num_boost_round=num_round,
                           # metrics='mlogloss',
                           valid_sets=D_val,
                           # valid_names='val',
                           # fobj=None,
                           # feval=None,
                           # init_model=None,
                           # feature_name='auto',
                           # categorical_feature='auto',
                           early_stopping_rounds=200,
                           # evals_result=None,
                           verbose_eval=False,
                           # learning_rates=None,
                           # keep_training_booster=False,
                           # callbacks=None
                           )

# %%
import pickle
with open('clf.pickle','wb') as f: #python路径要用反斜杠
    pickle.dump(clf,f)

# %%
test = pd.read_csv('C:/Users/Boniface/Desktop/房租预测/datasets/cluster_test.csv')
test.pop('Unnamed: 0')
test.pop('tradeMoney')
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 2464   NaN
# 2465   NaN
# 2466   NaN
# 2467   NaN
# 2468   NaN
# Name: tradeMoney, Length: 2469, dtype: float64

# %%
tradeMoney_predict = clf.predict(test ,num_iteration = clf.best_iteration)

# %%
result = pd.DataFrame(tradeMoney_predict)
result.to_csv('LBG_result.csv', header = False, index = False)

# %%
judge = pd.read_csv('C:/Users/Boniface/Desktop/房租预测/datasets/评分文件/sub_a_913.csv')
judge
# Out:
#        pre
# 0     4808
# 1     4770
# 2     5701
# 3     3635
# 4     4387
# ...    ...
# 2464  1890
# 2465  3693
# 2466  5206
# 2467  5714
# 2468  3656
#
# [2469 rows x 1 columns]

# %%
score = r2_score(judge, tradeMoney_predict)

# %%
print(score)
# Out:
# 0.9809248019322784
